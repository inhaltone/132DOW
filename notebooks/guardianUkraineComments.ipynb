# %%
import pandas as pd

comments_df = pd.read_csv('../data/raw/guardian/guard-articles-russia-comments.csv')
comments_df.head(30)
# Out:
#     Unnamed: 0                                              Title       key  \
# 0            0  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 1            1  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 2            2  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 3            3  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 4            4  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 5            5  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 6            6  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 7            7  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 8            8  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 9            9  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# 10          10  Keir Starmer urges Boris Johnson to end ‘era o...  /p/knqpm
# ...

# %%
comments_df.shape
# Out:
# (67478, 17)
